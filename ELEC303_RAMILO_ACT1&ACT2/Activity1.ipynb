# %% [markdown]
# <h1>Activity 1 - PALMER PENGUINS DATA ANALYTICS PROJECT </h1>
# <hr>
# <h3> Analyst : Mark Jayson Ramilo </h3>
# <HR>

# %%
#import libraries
import numpy as np
import pandas as pd

# %%
penguins = pd.read_csv('C:\\Users\\DESIREE\\Downloads\\datasets\\penguins.csv')

# %%
penguins
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %%
penguins.describe(). T
# Out:
#                    count         mean         std     min       25%      50%  \
# bill_length_mm     342.0    43.921930    5.459584    32.1    39.225    44.45
# bill_depth_mm      342.0    17.151170    1.974793    13.1    15.600    17.30
# flipper_length_mm  342.0   200.915205   14.061714   172.0   190.000   197.00
# body_mass_g        342.0  4201.754386  801.954536  2700.0  3550.000  4050.00
# year               344.0  2008.029070    0.818356  2007.0  2007.000  2008.00
#
#                       75%     max
# bill_length_mm       48.5    59.6
# bill_depth_mm        18.7    21.5
# flipper_length_mm   213.0   231.0
# body_mass_g        4750.0  6300.0
# year               2009.0  2009.0

# %%
penguins.isnull()
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      False   False           False          False              False
# 1      False   False           False          False              False
# 2      False   False           False          False              False
# 3      False   False            True           True               True
# 4      False   False           False          False              False
# ..       ...     ...             ...            ...                ...
# 339    False   False           False          False              False
# 340    False   False           False          False              False
# 341    False   False           False          False              False
# 342    False   False           False          False              False
# 343    False   False           False          False              False
#
#      body_mass_g    sex   year
# 0          False  False  False
# 1          False  False  False
# ...

# %%
penguins.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
penguins['species']
# Out:
# 0         Adelie
# 1         Adelie
# 2         Adelie
# 3         Adelie
# 4         Adelie
#          ...
# 339    Chinstrap
# 340    Chinstrap
# 341    Chinstrap
# 342    Chinstrap
# 343    Chinstrap
# Name: species, Length: 344, dtype: object

# %%
penguins['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
penguins['species'] == 'Chinstrap'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340     True
# 341     True
# 342     True
# 343     True
# Name: species, Length: 344, dtype: bool

# %%
penguins[penguins['species'] == 'Chinstrap']
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 276  Chinstrap  Dream            46.5           17.9              192.0
# 277  Chinstrap  Dream            50.0           19.5              196.0
# 278  Chinstrap  Dream            51.3           19.2              193.0
# 279  Chinstrap  Dream            45.4           18.7              188.0
# 280  Chinstrap  Dream            52.7           19.8              197.0
# ..         ...    ...             ...            ...                ...
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 340  Chinstrap  Dream            43.5           18.1              202.0
# 341  Chinstrap  Dream            49.6           18.2              193.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 276       3500.0  female  2007
# 277       3900.0    male  2007
# ...

# %%
adelie_df = penguins[penguins['species'] == 'Chinstrap']
adelie_df
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 276  Chinstrap  Dream            46.5           17.9              192.0
# 277  Chinstrap  Dream            50.0           19.5              196.0
# 278  Chinstrap  Dream            51.3           19.2              193.0
# 279  Chinstrap  Dream            45.4           18.7              188.0
# 280  Chinstrap  Dream            52.7           19.8              197.0
# ..         ...    ...             ...            ...                ...
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 340  Chinstrap  Dream            43.5           18.1              202.0
# 341  Chinstrap  Dream            49.6           18.2              193.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 276       3500.0  female  2007
# 277       3900.0    male  2007
# ...

# %%
gentoo_df = penguins[penguins['species'] == 'Gentoo']
gentoo_df
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152  Gentoo  Biscoe            46.1           13.2              211.0
# 153  Gentoo  Biscoe            50.0           16.3              230.0
# 154  Gentoo  Biscoe            48.7           14.1              210.0
# 155  Gentoo  Biscoe            50.0           15.2              218.0
# 156  Gentoo  Biscoe            47.6           14.5              215.0
# ..      ...     ...             ...            ...                ...
# 271  Gentoo  Biscoe             NaN            NaN                NaN
# 272  Gentoo  Biscoe            46.8           14.3              215.0
# 273  Gentoo  Biscoe            50.4           15.7              222.0
# 274  Gentoo  Biscoe            45.2           14.8              212.0
# 275  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  year
# 152       4500.0  female  2007
# 153       5700.0    male  2007
# ...

# %%
penguins['species'] == 'Chinstrap'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340     True
# 341     True
# 342     True
# 343     True
# Name: species, Length: 344, dtype: bool

# %%
 (penguins['body_mass_g'] >= 4000)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340    False
# 341    False
# 342     True
# 343    False
# Name: body_mass_g, Length: 344, dtype: bool

# %%
(penguins['species'] == 'Chinstrap') & (penguins['body_mass_g'] >= 4000)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340    False
# 341    False
# 342     True
# 343    False
# Length: 344, dtype: bool

# %%
penguins[(penguins['species'] == 'Chinstrap') & (penguins['body_mass_g'] >= 4000)]
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 284  Chinstrap  Dream            46.0           18.9              195.0
# 289  Chinstrap  Dream            52.0           18.1              201.0
# 291  Chinstrap  Dream            50.5           19.6              201.0
# 295  Chinstrap  Dream            49.2           18.2              195.0
# 301  Chinstrap  Dream            52.0           19.0              197.0
# 305  Chinstrap  Dream            52.8           20.0              205.0
# 307  Chinstrap  Dream            54.2           20.8              201.0
# 309  Chinstrap  Dream            51.0           18.8              203.0
# 313  Chinstrap  Dream            52.0           20.7              210.0
# 315  Chinstrap  Dream            53.5           19.9              205.0
# 321  Chinstrap  Dream            50.8           18.5              201.0
# 323  Chinstrap  Dream            49.0           19.6              212.0
# ...

# %%
chinstrap_heavy = penguins[(penguins['species'] == 'Chinstrap') & (penguins['body_mass_g'] >= 4000)]
chinstrap_heavy
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 284  Chinstrap  Dream            46.0           18.9              195.0
# 289  Chinstrap  Dream            52.0           18.1              201.0
# 291  Chinstrap  Dream            50.5           19.6              201.0
# 295  Chinstrap  Dream            49.2           18.2              195.0
# 301  Chinstrap  Dream            52.0           19.0              197.0
# 305  Chinstrap  Dream            52.8           20.0              205.0
# 307  Chinstrap  Dream            54.2           20.8              201.0
# 309  Chinstrap  Dream            51.0           18.8              203.0
# 313  Chinstrap  Dream            52.0           20.7              210.0
# 315  Chinstrap  Dream            53.5           19.9              205.0
# 321  Chinstrap  Dream            50.8           18.5              201.0
# 323  Chinstrap  Dream            49.0           19.6              212.0
# ...

# %% [markdown]
# <h2> FILLING UP NON VALUES <h2>
# <HR>

# %%
penguins.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
penguins['bill_length_mm']
# Out:
# 0      39.1
# 1      39.5
# 2      40.3
# 3       NaN
# 4      36.7
#        ...
# 339    55.8
# 340    43.5
# 341    49.6
# 342    50.8
# 343    50.2
# Name: bill_length_mm, Length: 344, dtype: float64

# %%
penguins['bill_length_mm'] . mean()
# Out:
# np.float64(43.9219298245614)

# %%
penguins['bill_length_mm'] = penguins['bill_length_mm'] .fillna(penguins['bill_length_mm'].mean())
penguins['bill_depth_mm'] = penguins['bill_depth_mm'] .fillna(penguins['bill_depth_mm'].mean())
penguins['flipper_length_mm'] = penguins['flipper_length_mm'] .fillna(penguins['flipper_length_mm'].mean())
penguins['body_mass_g'] = penguins['body_mass_g'] .fillna(penguins['body_mass_g'].mean())

# %%
penguins.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         0
# flipper_length_mm     0
# body_mass_g           0
# sex                  11
# year                  0
# dtype: int64

# %%
penguins['sex'] = penguins['sex'] .fillna(penguins['sex'] . mode()[0])

# %%
penguins.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# dtype: int64

# %% [markdown]
# <h2> CHANGING THE DATA TYPE <h2>
# <HR>

# %%
penguins['species'] = penguins['species'].astype('category')
penguins['island'] = penguins['island'].astype('category')
penguins['sex'] = penguins['sex'].astype('category')
penguins['year'] = penguins['year'].astype('category')

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    category
#  1   island             344 non-null    category
#  2   bill_length_mm     344 non-null    float64
#  3   bill_depth_mm      344 non-null    float64
#  4   flipper_length_mm  344 non-null    float64
#  5   body_mass_g        344 non-null    float64
#  6   sex                344 non-null    category
#  7   year               344 non-null    category
# dtypes: category(4), float64(4)
# memory usage: 12.7 KB

# %%
penguins['body_mass_g'].mean()
# Out:
# np.float64(4201.754385964912)

# %%
penguins['species'] == 'Gentoo'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: species, Length: 344, dtype: bool

# %% [markdown]
# <h4>How to Create a Column</h4>
# <HR>

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    category
#  1   island             344 non-null    category
#  2   bill_length_mm     344 non-null    float64
#  3   bill_depth_mm      344 non-null    float64
#  4   flipper_length_mm  344 non-null    float64
#  5   body_mass_g        344 non-null    float64
#  6   sex                344 non-null    category
#  7   year               344 non-null    category
# dtypes: category(4), float64(4)
# memory usage: 12.7 KB

# %%
penguins.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex', 'year'],
#       dtype='object')

# %%
penguins['mass_kg'] = np.round(penguins['body_mass_g'] / 1000 , 1)

# %%
penguins
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen        39.10000       18.70000         181.000000
# 1       Adelie  Torgersen        39.50000       17.40000         186.000000
# 2       Adelie  Torgersen        40.30000       18.00000         195.000000
# 3       Adelie  Torgersen        43.92193       17.15117         200.915205
# 4       Adelie  Torgersen        36.70000       19.30000         193.000000
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream        55.80000       19.80000         207.000000
# 340  Chinstrap      Dream        43.50000       18.10000         202.000000
# 341  Chinstrap      Dream        49.60000       18.20000         193.000000
# 342  Chinstrap      Dream        50.80000       19.00000         210.000000
# 343  Chinstrap      Dream        50.20000       18.70000         198.000000
#
#      body_mass_g     sex  year  mass_kg
# ...

# %%
penguins['mass_kg'].max()
# Out:
# np.float64(6.3)

# %% [markdown]
# penguins[penguins['mass_kg'] == 6.3]

# %% [markdown]
# <h2>Exploratory Data Analytics</h2>
# <HR>

# %%
penguins
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen        39.10000       18.70000         181.000000
# 1       Adelie  Torgersen        39.50000       17.40000         186.000000
# 2       Adelie  Torgersen        40.30000       18.00000         195.000000
# 3       Adelie  Torgersen        43.92193       17.15117         200.915205
# 4       Adelie  Torgersen        36.70000       19.30000         193.000000
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream        55.80000       19.80000         207.000000
# 340  Chinstrap      Dream        43.50000       18.10000         202.000000
# 341  Chinstrap      Dream        49.60000       18.20000         193.000000
# 342  Chinstrap      Dream        50.80000       19.00000         210.000000
# 343  Chinstrap      Dream        50.20000       18.70000         198.000000
#
#      body_mass_g     sex  year  mass_kg
# ...

# %% [markdown]
# <h2>QUESTION 1</h2>
# <HR>
# <h4>Which specie has the lightiest body mass?</h4>

# %%
gento_df = penguins[penguins['species'] == 'Gentoo']
gento_df['body_mass_g'].mean()
# Out:
# np.float64(5068.965761177136)

# %%
gento_df = penguins[penguins['species'] == 'Chinstrap']
gento_df['body_mass_g'].mean()
# Out:
# np.float64(3733.0882352941176)

# %%
adelie_df = penguins[penguins['species'] == 'Adelie']
adelie_df['body_mass_g'].mean()
# Out:
# np.float64(3703.95891043398)

# %% [markdown]
# <h2>INSIGHT NO 1</h2>
# <HR>
# <h4>Adelie has the lightiest average body mass</h4>

# %% [markdown]
# <h2>QUESTION 2</h2>
# <HR>
# <h4>Which species has the longest flipper?</h4>

# %%
gento_df = penguins[penguins['species'] == 'Gentoo']
gento_df['flipper_length_mm'].mean()
# Out:
# np.float64(217.05576777966422)

# %%
chinstrap_df = penguins[penguins['species'] == 'Chinstrap']
chinstrap_df['flipper_length_mm'].mean()
# Out:
# np.float64(195.8235294117647)

# %%
adelie_df = penguins[penguins['species'] == 'Adelie']
adelie_df['flipper_length_mm'].mean()
# Out:
# np.float64(190.02575792551556)

# %% [markdown]
# <h2>INSIGHT 2</h2>
# <HR>
# <h4>Gento has the longest flipper among all the species</h4>

# %% [markdown]
# <h2>QUESTION 3</h2>
# <HR>
# <h4>What is the average flipper length of female adelie?</h4>

# %%
female_adelie = penguins[(penguins["species"] == "Adelie") & (penguins["sex"] == "female")]

female_adelie
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 6    Adelie  Torgersen            38.9           17.8              181.0
# 12   Adelie  Torgersen            41.1           17.6              182.0
# ..      ...        ...             ...            ...                ...
# 142  Adelie      Dream            32.1           15.5              188.0
# 144  Adelie      Dream            37.3           16.8              192.0
# 147  Adelie      Dream            36.6           18.4              184.0
# 148  Adelie      Dream            36.0           17.8              195.0
# 150  Adelie      Dream            36.0           17.1              187.0
#
#      body_mass_g     sex  year  mass_kg
# 1         3800.0  female  2007      3.8
# ...

# %%
average_flipper_length = female_adelie["flipper_length_mm"].mean()
average_flipper_length
# Out:
# np.float64(187.7945205479452)

# %% [markdown]
# <h2>INSIGHT 3</h2>
# <HR>
# <h4>The average flipper length of female adelie is 187.7 mm.</h4>

# %% [markdown]
# <h2>QUESTION 4</h2>
# <HR>
# <h4>What is the average bill length of male gentoo in the year 2009?</h4>

# %%
female_gentoo_2009 = penguins[(penguins["species"] == "Gentoo") & (penguins["sex"] == "male") & (penguins["year"] == 2009)]
female_gentoo_2009
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 233  Gentoo  Biscoe        52.50000       15.60000         221.000000
# 235  Gentoo  Biscoe        50.00000       15.90000         224.000000
# 237  Gentoo  Biscoe        50.80000       17.30000         228.000000
# 239  Gentoo  Biscoe        51.30000       14.20000         218.000000
# 241  Gentoo  Biscoe        52.10000       17.00000         230.000000
# 243  Gentoo  Biscoe        52.20000       17.10000         228.000000
# 245  Gentoo  Biscoe        49.50000       16.10000         224.000000
# 247  Gentoo  Biscoe        50.80000       15.70000         226.000000
# 248  Gentoo  Biscoe        49.40000       15.80000         216.000000
# 251  Gentoo  Biscoe        51.10000       16.50000         225.000000
# 253  Gentoo  Biscoe        55.90000       17.00000         228.000000
# 255  Gentoo  Biscoe        49.10000       15.00000         228.000000
# ...

# %%
avg_bill_length = female_gentoo_2009["bill_length_mm"].mean()
print(avg_bill_length)
# Out:
# 50.17591374269006

# %% [markdown]
# <h2>INSIGHT.4</h2>
# <HR>
# <h4>The average bill length of male gentoo is 50.8 mm.</h4>

# %% [markdown]
# <h2>QUESTION 5</h2>
# <HR>
# <h4>What is the heaviest body mass of male chinstrap??</h4>

# %%
male_chinstrap = penguins[(penguins["species"] == "Chinstrap") & (penguins["sex"] == "male")]
male_chinstrap
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 277  Chinstrap  Dream            50.0           19.5              196.0
# 278  Chinstrap  Dream            51.3           19.2              193.0
# 280  Chinstrap  Dream            52.7           19.8              197.0
# 283  Chinstrap  Dream            51.3           18.2              197.0
# 285  Chinstrap  Dream            51.3           19.9              198.0
# 287  Chinstrap  Dream            51.7           20.3              194.0
# 289  Chinstrap  Dream            52.0           18.1              201.0
# 291  Chinstrap  Dream            50.5           19.6              201.0
# 292  Chinstrap  Dream            50.3           20.0              197.0
# 295  Chinstrap  Dream            49.2           18.2              195.0
# 297  Chinstrap  Dream            48.5           17.5              191.0
# 299  Chinstrap  Dream            50.6           19.4              193.0
# ...

# %%
heaviest_mass = male_chinstrap["body_mass_g"].max()
heaviest_mass
# Out:
# np.float64(4800.0)

# %% [markdown]
# <h2>INSIGHT 5</h2>
# <HR>
# <h4> The highest body mass of male chinstrap is 4800</h4>

# %% [markdown]
# <h2>QUESTION 6</h2>
# <HR>
# <h4>What is the heaviest body mass of female gentoo?</h4>

# %%
female_gentoo = penguins[(penguins["species"] == "Gentoo") & (penguins["sex"] == "female")]
female_gentoo
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152  Gentoo  Biscoe            46.1           13.2              211.0
# 154  Gentoo  Biscoe            48.7           14.1              210.0
# 157  Gentoo  Biscoe            46.5           13.5              210.0
# 158  Gentoo  Biscoe            45.4           14.6              211.0
# 160  Gentoo  Biscoe            43.3           13.4              209.0
# 162  Gentoo  Biscoe            40.9           13.7              214.0
# 164  Gentoo  Biscoe            45.5           13.7              214.0
# 166  Gentoo  Biscoe            45.8           14.6              210.0
# 168  Gentoo  Biscoe            42.0           13.5              210.0
# 170  Gentoo  Biscoe            46.2           14.5              209.0
# 173  Gentoo  Biscoe            45.1           14.5              215.0
# 174  Gentoo  Biscoe            46.5           14.5              213.0
# ...

# %%
heaviest_mass = female_gentoo["body_mass_g"].max()
heaviest_mass
# Out:
# np.float64(5200.0)

# %% [markdown]
# <h2>INSIGHT 6</h2>
# <HR>
# <h4> The highest body mass of female gentoo is 5200.</h4>

# %% [markdown]
# <h2>QUESTION 7</h2>
# <HR>
# <h4>What is the highest bill depth of adelie in the year 2007?</h4>

# %%
adelie_2007 = penguins[(penguins["species"] == "Adelie") & (penguins["year"] == 2007)]
adelie_2007
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen        39.10000       18.70000         181.000000
# 1   Adelie  Torgersen        39.50000       17.40000         186.000000
# 2   Adelie  Torgersen        40.30000       18.00000         195.000000
# 3   Adelie  Torgersen        43.92193       17.15117         200.915205
# 4   Adelie  Torgersen        36.70000       19.30000         193.000000
# 5   Adelie  Torgersen        39.30000       20.60000         190.000000
# 6   Adelie  Torgersen        38.90000       17.80000         181.000000
# 7   Adelie  Torgersen        39.20000       19.60000         195.000000
# 8   Adelie  Torgersen        34.10000       18.10000         193.000000
# 9   Adelie  Torgersen        42.00000       20.20000         190.000000
# 10  Adelie  Torgersen        37.80000       17.10000         186.000000
# 11  Adelie  Torgersen        37.80000       17.30000         180.000000
# ...

# %%
highest_bill_depth = adelie_2007["bill_depth_mm"].max()
highest_bill_depth
# Out:
# np.float64(21.5)

# %% [markdown]
# <h2>INSIGHT 7</h2>
# <HR>
# <h4> The highest bill depth of adelie in the year 2009 is 21.5</h4>

# %% [markdown]
# <h2>QUESTION 8</h2>
# <HR>

# %% [markdown]
# <h4>What is the average body mass of male Adelie penguins?</h4>

# %%
male_adelie = penguins[(penguins["species"] == "Adelie") & (penguins["sex"] == "male")]
male_adelie["body_mass_g"].mean()
# Out:
# np.float64(4013.6298023539866)

# %% [markdown]
# <h2>INSIGHT 8</h2>
# <HR>
# <H4>The average body mass of male Adelie penguins is 4013.63 g.</H4>

# %% [markdown]
# <h2>QUESTION 9</h2>
# <HR>

# %% [markdown]
# <H4>Which year has the highest average flipper length?</H4>

# %%
years = penguins["year"].unique()
highest_year = None
highest_avg = 0

for y in years:
    avg_flipper = penguins[penguins["year"] == y]["flipper_length_mm"].mean()
    if avg_flipper > highest_avg:
        highest_avg = avg_flipper
        highest_year = y

highest_year, highest_avg
# Out:
# (2008, np.float64(202.7982456140351))

# %% [markdown]
# <H2>INSIGHT 9</H2>
# <HR>
# <H4>The year with the highest average flipper length is 2008, with an average of 202.80 mm.</H4>

# %% [markdown]
# <H2>QUESTION 10</H2>
# <HR>

# %% [markdown]
# <H4>What is the average bill depth of Chinstrap penguins?</H4>

# %%
chinstrap = penguins[penguins["species"] == "Chinstrap"]
chinstrap["bill_depth_mm"].mean()
# Out:
# np.float64(18.42058823529412)

# %% [markdown]
# <H2>INSIGHT 10</H2>
# <HR>
# <H4>The average bill depth of Chinstrap penguins is 18.42 mm.</H4>

# %% [markdown]
# <H2>QUESTION 11</H2>
# <HR>

# %% [markdown]
# <H4>Which species has the widest range in body mass (max - min)?</H4>

# %%
species = penguins["species"].unique()
widest_species = None
widest_range = 0

for s in species:
    data = penguins[penguins["species"] == s]["body_mass_g"]
    mass_range = data.max() - data.min()
    if mass_range > widest_range:
        widest_range = mass_range
        widest_species = s

widest_species, widest_range
# Out:
# ('Gentoo', np.float64(2350.0))

# %% [markdown]
# <H2>INSIGHT 11</H2>
# <HR>
# <H4>The species with the widest range in body mass is Gentoo, with a range of 2350 g.</H4>

# %% [markdown]
# <h2>QUESTION 12</h2>
# <HR>

# %% [markdown]
# <H4>What is the average flipper length of female Gentoo penguins?</H4>

# %%
male_adelie = penguins[(penguins["species"] == "Adelie") & (penguins["sex"] == "male")]
male_adelie["body_mass_g"].mean()
# Out:
# np.float64(4013.6298023539866)

# %% [markdown]
# <H2>INSIGHT 12</H2>
# <HR>
# <H4>The average flipper length of female Gentoo penguins is 211.02 mm.</H4>

# %% [markdown]
# <h2>QUESION 13</h2>
# <HR>

# %% [markdown]
# <h4>Which island has the highest average penguin body mass?</h4>

# %%
islands = penguins["island"].unique()
heaviest_island = None
highest_avg_mass = 0

for i in islands:
    avg_mass = penguins[penguins["island"] == i]["body_mass_g"].mean()
    if avg_mass > highest_avg_mass:
        highest_avg_mass = avg_mass
        heaviest_island = i

heaviest_island, highest_avg_mass
# Out:
# ('Biscoe', np.float64(4712.95687134503))

# %% [markdown]
# <h2>INSIGHT 13</h2>
# <HR>
# <H4>The island with the highest average penguin body mass is Biscoe, with an average of 4712.96 g.</H4>
